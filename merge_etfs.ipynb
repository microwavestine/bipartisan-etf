# %%
import re
import csv

NANC_CSV_FILE = "10-80-NANC-N-PORT-Part-F-123123-V5-Confidential.csv"
KRUZ_CSV_FILE = "11-81-KRUZ-N-PORT-Part-F-123123-V5-Confidential.pdf-00-48-16-852.csv"

NANC_STOCKS = set()
KRUZ_STOCKS = set()
with open(NANC_CSV_FILE, newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        number_filter = re.search("[0-9]+(\.[0-9]+)?%", row[0]) # don't need lines with just with numbers
        # print(row)
        if not (number_filter) and (
                "Inc" in row[0] or 
                "Corp" in row[0] or 
                "Co" in row[0] or 
                "PLC" in row[0] or
                "ADR" in row[0] or
                "Ltd" in row[0] or
                "AG" in row[0] or
                "Bancorp" in row[0]
                ):
            row[0] = re.sub(r'[\x00-\x1f]+', '', row[0]) # cleanup: replaces \xad or \xad\x0c by nothing
            if re.search(" {2,}", row[0]):
                # ['Silgan Holdings, Inc.                                      44           1,991']
                # cleanup: for these kind of rows where there's ridiculous amount of spacing due to table view
                row[0] = re.sub('[0-9,,,.,§]', '', row[0])
                row[0] = row[0].strip()
                #print(row)
                NANC_STOCKS.add(row[0])
            else:
                #print(row)
                NANC_STOCKS.add(row[0])

# print(NANC_STOCKS)

with open(KRUZ_CSV_FILE, newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        number_filter = re.search("[0-9]+(\.[0-9]+)?%", row[0]) # don't need lines with just with numbers
        # print(row)
        if not (number_filter) and (
                "Inc" in row[0] or 
                "Corp" in row[0] or 
                "Co" in row[0] or 
                "PLC" in row[0] or
                "ADR" in row[0] or
                "Ltd" in row[0] or
                "AG" in row[0] or
                "Bancorp" in row[0]
                ):
            row[0] = re.sub(r'[\x00-\x1f]+', '', row[0]) # cleanup: replaces \xad or \xad\x0c by nothing
            if re.search(" {2,}", row[0]):
                # ['Silgan Holdings, Inc.                                      44           1,991']
                # cleanup: for these kind of rows where there's ridiculous amount of spacing due to table view
                row[0] = re.sub('[0-9,,,.,§]', '', row[0])
                row[0] = row[0].strip()
                #print(row)
                KRUZ_STOCKS.add(row[0])
            else:
                #print(row)
                KRUZ_STOCKS.add(row[0])

# print(NANC_STOCKS.intersection(KRUZ_STOCKS))
# print(NANC_STOCKS - KRUZ_STOCKS)
# print(KRUZ_STOCKS - NANC_STOCKS)

# %%
import pandas as pd

# %%
BIPARTISAN_STOCKS = list(NANC_STOCKS.intersection(KRUZ_STOCKS))

# %%
dataframe = pd.DataFrame(BIPARTISAN_STOCKS, columns=["Stocks"])

# %%
with pd.option_context('display.max_rows', None,):
    print(dataframe)
# Out:
#                                          Stocks
# 0                          Freeport-McMoRan Inc
# 1                                      CSX Corp
# 2                         Micron Technology Inc
# 3                         Bath & Body Works Inc
# 4                  Citizens Financial Group Inc
# 5                                   Southern Co
# 6                                     Aflac Inc
# 7                           Elevance Health Inc
# 177                               Ford Motor Co
# 178                                 Oracle Corp
# 179                 Willis Towers Watson PLC(b)
# 180                              Microsoft Corp
# 181                         American Tower Corp
# 182                           ‘Amazoncom Inc(a)
# 183                          Domino's Pizza Inc
# 184                             Xcel Energy Inc
# 185                         Dollar General Corp
# 186                          Dollar Tree Inc(a)
# 187                  Raytheon Technologies Corp
# 188                             Caterpillar Inc
# 189                              AptarGroup Inc
# 190                         Emerson Electric Co
# 191               Meta Platforms Inc Class A(a)
# 192          Mondelez International Inc Class A
# 193                               Dexcom Inc(a)
# 194                             AutoZone Inc(a)
# 195                              Netflix Inc(a)
# 196       Hartford Financial Services Group Inc
# 197                                Woodward Inc
# 198                            Exxon Mobil Corp
# 199                                     KeyCorp
# 200                       AstraZeneca PLC - ADR
# 201                       Airbnb Inc Class A(a)
# 202                  LPL Financial Holdings Inc
# 203                        Las Vegas Sands Corp
# 204                                KKR & Co Inc
# 205                           ServiceNow Inc(a)
# 206                                     Gap Inc
# 207  Fidelity National Information Services Inc
# 208                         Kimberly-Clark Corp
# 209                            NIKE Inc Class B
# 210                      llinois Tool Works Inc
# 211                         Fifth Third Bancorp
# 212                               BlackRock Inc
# 213                    Accenture PLC Class A(b)
# 214               Old Dominion Freight Line Inc
# 215                             Baker Hughes Co
# 216                      International Paper Co
# 217                                Teradyne Inc
# 218                        Parker-Hannifin Corp
# 219                         Rio Tinto PLC - ADR
# 220                   Palo Alto Networks Inc(a)
# 221                                   ONEOK Inc
# 222                         General Electric Co
# 223                            Progressive Corp
# 224                              S&P Global Inc
# 225              American Electric Power Co Inc
# 226                             Gen Digital Inc
# 227                                 Cummins Inc
# 228                                   Mosaic Co
# 229                                  Hershey Co
# 230                      ROBLOX Corp Class A(a)
# 231                           Kinder Morgan Inc
# 232                                Chubb Ltd(b)
# 233                           Salesforce Inc(a)
# 234                     Cleveland-Cliffs Inc(a)
# 235                                QUALCOMM Inc
# 236                                 Hexcel Corp
# 237                                Tesla Inc(a)
# 238                              Home Depot Inc
# 239                             Fortinet Inc(a)
# 240                             McDonald's Corp
# 241                              PulteGroup Inc
# 242                             Centene Corp(a)
# 243                   Boston Scientific Corp(a)
# 244                             Allegion PLC(b)
# 245                     Goldman Sachs Group Inc
# 246         BJ's Wholesale Club Holdings Inc(a)
# 247                         Gilead Sciences Inc
# 248                                  Dover Corp
# 249                           Omnicom Group Inc
# 250                         Markel Group Inc(a)
# 251                           General Mills Inc
# 252                                 Etsy Inc(a)
# 253                     Alphabet Inc Class C(a)
# 254                         Charles Schwab Corp
# 255                                 Target Corp
# 256                                        M Co
# 257                       Delta Air Lines, Inc.
# 258                  Capital One Financial Corp
# 259                                Coca-Cola Co
# 260                         American Express Co
# 261                        Lockheed Martin Corp
# 262                                Danaher Corp
# 263                          NextEra Energy Inc
# 264                                Adobe Inc(a)
